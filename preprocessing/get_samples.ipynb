# %%
# This script reads a csv file containing run length encoded segmentation labels,
# creates the encoded binary images and saves them 

# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Path to train images
input_path = '/content/drive/MyDrive/Deep_learning/project/data/train/'
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import numpy as np
import cv2
from google.colab.patches import cv2_imshow


ind = 1
for f in os.listdir(input_path):
    if f.find(".png") != -1:
        img = cv2.imread(f"{input_path}{f}",0)

        cv2_imshow(img)
        if ind == 5:
          break
        ind += 1
# Out:
# <PIL.Image.Image image mode=L size=704x520 at 0x7EFC8A803D50>
# <PIL.Image.Image image mode=L size=704x520 at 0x7EFC8A795310>
# <PIL.Image.Image image mode=L size=704x520 at 0x7EFC8A78F690>
# <PIL.Image.Image image mode=L size=704x520 at 0x7EFC8A795310>
# <PIL.Image.Image image mode=L size=704x520 at 0x7EFC8A795310>
